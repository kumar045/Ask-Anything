# %% [markdown]
# <a href="https://colab.research.google.com/github/kumar045/Ask-Anything/blob/main/Advanced_AI_Translation_with_Facebook's_No_Language_Left_Behind.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
! pip install https://github.com/huggingface/transformers/archive/nllb.zip -q
# Out:
#      - 12.2 MB 8.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 6.6 MB 5.0 MB/s
#      |████████████████████████████████| 596 kB 53.2 MB/s
#      |████████████████████████████████| 101 kB 13.8 MB/s
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")
tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")

# %%
translator = pipeline('translation', model=model, tokenizer=tokenizer, src_lang="tam_Taml", tgt_lang='eng_Latn', max_length = 400)

# %%
translator("திஸ் ஐஸ் எ வெரி குட் மாடல் ")
# Out:
# [{'translation_text': 'The Is a Very Good Model.'}]
